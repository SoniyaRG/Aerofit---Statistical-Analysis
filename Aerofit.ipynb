# %%
# STEP 1 : IMPORT ALL THE NECESSARY LIBRARY
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#Read the file
df = pd.read_csv('aerofit.csv')

# %%
df
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     KP281   18    Male         14        Single      3        4   29562
# 1     KP281   19    Male         15        Single      2        3   31836
# 2     KP281   19  Female         14     Partnered      4        3   30699
# 3     KP281   19    Male         12        Single      3        3   32973
# 4     KP281   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   KP781   40    Male         21        Single      6        5   83416
# 176   KP781   42    Male         18        Single      5        4   89641
# 177   KP781   45    Male         16        Single      5        5   90886
# 178   KP781   47    Male         18     Partnered      4        5  104581
# 179   KP781   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %%
df.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   KP281   18    Male         14        Single      3        4   29562    112
# 1   KP281   19    Male         15        Single      2        3   31836     75
# 2   KP281   19  Female         14     Partnered      4        3   30699     66
# 3   KP281   19    Male         12        Single      3        3   32973     85
# 4   KP281   20    Male         13     Partnered      4        2   35247     47

# %%
#From below , we can say that 3 are categorical while other are numerical columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
df.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %%
# No. of columns are 9 while rows are 180
df.shape
# Out:
# (180, 9)

# %%
#STEP 2 : DATA CLEANING

# %%
#Checking if any null
df.isnull().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %%
duplicate = df[df.duplicated()]
duplicate
#from above we can say that data is clean since there is no null values, no duplicate rows
# Out:
# Empty DataFrame
# Columns: [Product, Age, Gender, Education, MaritalStatus, Usage, Fitness, Income, Miles]
# Index: []

# %%
# STEP 3: DATA EXPLORATION

# %%
df.nunique()
# Out:
# Product           3
# Age              32
# Gender            2
# Education         8
# MaritalStatus     2
# Usage             6
# Fitness           5
# Income           62
# Miles            37
# dtype: int64

# %%
df.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   KP281   18    Male         14        Single      3        4   29562    112
# 1   KP281   19    Male         15        Single      2        3   31836     75
# 2   KP281   19  Female         14     Partnered      4        3   30699     66
# 3   KP281   19    Male         12        Single      3        3   32973     85
# 4   KP281   20    Male         13     Partnered      4        2   35247     47

# %%
gender = df.Gender.value_counts()
gender
# Out:
# Gender
# Male      104
# Female     76
# Name: count, dtype: int64

# %%
MaritalStatus = df.MaritalStatus.value_counts()
MaritalStatus
# Out:
# MaritalStatus
# Partnered    107
# Single        73
# Name: count, dtype: int64

# %%
Product = df.Product.value_counts()
Product
# Out:
# Product
# KP281    80
# KP481    60
# KP781    40
# Name: count, dtype: int64

# %%
#Univariate Analysis

# %%
#1. Analysis of Categorial Variables

# %%
x_gender = gender.index
y_gender = gender

x_marital = MaritalStatus.index
y_marital = MaritalStatus

x_Product = Product.index
y_Product = Product

plt.figure(figsize = (10,5))

plt.subplot(1, 3, 1) 
plt.bar(x_gender, y_gender, color='skyblue')
plt.title("Number of Female and Male")
plt.xlabel("Gender", fontsize=12)
plt.ylabel("Count", fontsize=12)

plt.subplot(1, 3, 2)  # 1 row, 2 columns, 1st subplot
plt.bar(x_marital, y_marital, color='lightgreen')
plt.title("Count Of Marital Status")
plt.xlabel("Marital Status", fontsize=12)
plt.ylabel("Count", fontsize=12)

plt.subplot(1, 3, 3)  # 1 row, 2 columns, 1st subplot
plt.bar(x_Product, y_Product, color='red')
plt.title("Count Of Products")
plt.xlabel("Product", fontsize=12)
plt.ylabel("Count", fontsize=12)

plt.tight_layout()
plt.show()

# %%
df.Age.min()
# Out:
# 18

# %%
df.Age.max()
# Out:
# 50

# %%
#2. Analysis of Numerical Variables
fig, axs = plt.subplots(3, 2, figsize=(11,11))

sns.histplot(data=df, x="Age", kde=True, color="skyblue", ax=axs[0, 0])
sns.histplot(data=df, x="Education", kde=True, color="blue", ax=axs[0, 1])
sns.histplot(data=df, x="Usage", kde=True, color="orange", ax=axs[1, 0])
sns.histplot(data=df, x="Fitness", kde=True, color="red", ax=axs[1, 1])
sns.histplot(data=df, x="Income", kde=True, color="purple", ax=axs[2, 0])
sns.histplot(data=df, x="Miles", kde=True, color="yellow", ax=axs[2, 1])

plt.show()

# %%
#Outliers using boxplot

# %%
fig, axis = plt.subplots(nrows=3, ncols=2, figsize=(9, 9))
fig.subplots_adjust(top=1.0)
sns.boxplot(data=df, x="Age", orient='h', ax=axis[0,0])
sns.boxplot(data=df, x="Education", orient='h', ax=axis[0,1])
sns.boxplot(data=df, x="Usage", orient='h', ax=axis[1,0])
sns.boxplot(data=df, x="Fitness", orient='h', ax=axis[1,1])
sns.boxplot(data=df, x="Income", orient='h', ax=axis[2,0])
sns.boxplot(data=df, x="Miles", orient='h', ax=axis[2,1])
plt.show()

# %%
# from above Box plot,
# For Age , Education , Usage ,  Fitness outliers are very few.
# For Income , miles outliers are more than the rest.

# %%
#Bivariate

# %%
# 1.lets see if the product has any impact based on Gender and Marital Status
sns.set_style(style='whitegrid')
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(10, 6.5))
sns.countplot(data=df, x='Product', hue='Gender', edgecolor="0.15",
palette='PRGn', ax=axs[0])
sns.countplot(data=df, x='Product', hue='MaritalStatus',
edgecolor="0.15", palette='RdYlBu', ax=axs[1])
axs[0].set_title("Product vs Gender", pad=10, fontsize=14)
axs[1].set_title("Product vs Marital Status", pad=10, fontsize=14)
plt.show()

# %%
# 2.lets see if the product has any impact based on Numerical info of columns
a = ['Age', 'Education', 'Usage', 'Fitness', 'Income',
'Miles']
sns.set_style("white")
fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(12, 8))
fig.subplots_adjust(top=1.2)
count = 0

for i in range(2):
     for j in range(3):
            sns.boxplot(data=df, x='Product', y=a[count],
            ax=axs[i,j], palette='Set1')
            axs[i,j].set_title(f"Product vs {a[count]}",
            pad=8, fontsize=13)
            count += 1

# %%
#Multivariate

# %%
sns.pairplot(df, hue='Gender', vars=['Age', 'Education', 'Income', 'Miles'])
plt.title('Pair Plot with Gender Hue')
plt.show()

# %%
sns.pairplot(df, hue='Product', vars=['Age', 'Education', 'Income', 'Miles'])
plt.title('Pair Plot with Gender Hue')
plt.show()

# %%
numeric_df = df.select_dtypes(include=['number'])

# Compute the correlation matrix
corr_mat = numeric_df.corr()

# Plot the heatmap
plt.figure(figsize=(15,6))
sns.heatmap(corr_mat, annot=True, cmap="YlGnBu", fmt=".2f")
plt.show()

# %%
#Statistical and Probability Analysis

# %%
df.head(2)
# Out:
#   Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   KP281   18   Male         14        Single      3        4   29562    112
# 1   KP281   19   Male         15        Single      2        3   31836     75

# %%
# Marginal Probability affecting Product based on Gender
# Calculate frequencies
joint_freq = pd.crosstab(df['Product'], df['Gender'])
product_freq = df['Product'].value_counts()
gender_freq = df['Gender'].value_counts()

# Calculate joint probabilities
joint_prob = joint_freq / joint_freq.sum().sum()

# Calculate marginal probabilities
product_prob = product_freq / product_freq.sum()
gender_prob = gender_freq / gender_freq.sum()

# Calculate conditional probabilities
# P(Gender|Product) = P(Gender ∩ Product) / P(Product)
conditional_prob = joint_prob.div(product_prob, axis=0)


print("Conditional Probabilities P(Gender|Product):")
print(conditional_prob)
# Out:
# Conditional Probabilities P(Gender|Product):
# Gender     Female      Male
# Product
# KP281    0.500000  0.500000
# KP481    0.483333  0.516667
# KP781    0.175000  0.825000

# %%
# customer profilings for each and every product
products = df['Product'].unique()

# Dictionary to hold profiling results
profile_results = {}

# Compute profiles for each product
for product in products:
    df_product = df[df['Product'] == product]
    
    # Descriptive statistics
    age_stats = df_product['Age'].describe()
    income_stats = df_product['Income'].describe()
    gender_distribution = df_product['Gender'].value_counts(normalize=True)
    
    # Store results
    profile_results[product] = {
        'Age Statistics': age_stats,
        'Income Statistics': income_stats,
        'Gender Distribution': gender_distribution
    }


for product, profile in profile_results.items():
    print(f"\nProfile for Product {product}:")
    print("Age Statistics:")
    print(profile['Age Statistics'])
    print("\nIncome Statistics:")
    print(profile['Income Statistics'])
    print("\nGender Distribution:")
    print(profile['Gender Distribution'])
# Out:
# Profile for Product KP281:
# Age Statistics:
# count    80.000000
# mean     28.550000
# std       7.221452
# min      18.000000
# 25%      23.000000
# 50%      26.000000
# 75%      33.000000
# max      50.000000
# Name: Age, dtype: float64
#
# Income Statistics:
# count       80.00000
# mean     46418.02500
# std       9075.78319
# min      29562.00000
# 25%      38658.00000
# 50%      46617.00000
# 75%      53439.00000
# max      68220.00000
# Name: Income, dtype: float64
#
# Gender Distribution:
# Gender
# Male      0.5
# Female    0.5
# Name: proportion, dtype: float64
#
# Profile for Product KP481:
# Age Statistics:
# count    60.000000
# mean     28.900000
# std       6.645248
# min      19.000000
# 25%      24.000000
# 50%      26.000000
# 75%      33.250000
# max      48.000000
# Name: Age, dtype: float64
#
# Income Statistics:
# count       60.000000
# mean     48973.650000
# std       8653.989388
# min      31836.000000
# 25%      44911.500000
# 50%      49459.500000
# ...
